# %%
import cv2
import pickle
import numpy as np
import os
video=cv2.VideoCapture(0)
facedetect=cv2.CascadeClassifier('data/haarcascade_frontalface_default.xml')

faces_data=[]

i=0

name=input("Enter Your Name: ")

while True:
    ret,frame=video.read()
    gray=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces=facedetect.detectMultiScale(gray, 1.3 ,5)
    for (x,y,w,h) in faces:
        crop_img=frame[y:y+h, x:x+w, :]
        resized_img=cv2.resize(crop_img, (50,50))
        print(resized_img)
        i=i+1
        cv2.putText(frame, str(i), (50,50), cv2.FONT_HERSHEY_COMPLEX, 1, (50,50,255), 1)
        cv2.rectangle(frame, (x,y), (x+w, y+h), (50,50,255), 1)
    cv2.imshow("Frame",frame)
    k=cv2.waitKey(1)
    if k==ord('q') or i==10:
        break
video.release()
cv2.destroyAllWindows()
# Out:
# Enter Your Name:  piyush
# [[[ 25  24  28]
#   [ 27  22  28]
#   [ 29  23  27]
#   ...
#   [160 157 162]
#   [120 122 126]
#   [175 175 189]]
#
#  [[ 22  24  26]
#   [ 26  22  27]
#   [ 28  24  28]
#   ...
#   [ 91  81  87]
#   [130 128 135]
#   [148 151 163]]
#
#  [[ 23  22  26]
#   [ 28  22  29]
#   [ 28  22  30]
#   ...
#   [ 90  80  91]
#   [126 118 138]
#   [161 163 187]]
#
#  ...
#
#  [[ 71  68 122]
#   [ 50  45 130]
#   [ 56  53 139]
#   ...
#   [ 27  42  64]
#   [ 30  45  68]
#   [ 31  45  67]]
#
#  [[ 57  65 111]
#   [ 47  46 121]
#   [ 54  51 140]
#   ...
#   [ 25  40  62]
#   [ 28  39  62]
#   [ 32  43  65]]
#
#  [[ 51  56 109]
#   [ 56  49 122]
#   [ 61  49 138]
#   ...
#   [ 24  37  59]
#   [ 24  37  59]
#   [ 32  44  66]]]
# [[[ 23  22  24]
#   [ 22  20  25]
#   [ 25  24  28]
#   ...
#   [171 169 171]
#   [127 126 130]
#   [154 152 165]]
#
#  [[ 21  19  24]
#   [ 23  21  26]
#   [ 25  21  26]
#   ...
#   [105 100 104]
#   [129 130 135]
#   [164 166 176]]
#
#  [[ 26  20  25]
#   [ 20  17  25]
#   [ 24  20  26]
#   ...
#   [ 79  67  78]
#   [104  95 109]
#   [147 145 159]]
#
#  ...
#
#  [[ 59  64 116]
#   [ 50  49 118]
#   [ 49  46 128]
#   ...
#   [ 28  38  64]
#   [ 26  36  61]
#   [ 25  38  64]]
#
#  [[ 48  55 103]
#   [ 43  44 111]
#   [ 47  43 123]
#   ...
#   [ 26  35  59]
#   [ 26  38  61]
#   [ 28  39  67]]
#
#  [[ 42  51 100]
#   [ 42  46 111]
#   [ 46  45 128]
#   ...
#   [ 29  37  61]
#   [ 28  35  62]
#   [ 26  34  63]]]
# [[[ 24  21  23]
#   [ 25  19  21]
#   [ 21  18  19]
#   ...
#   [173 168 171]
#   [106 103 108]
#   [145 141 150]]
#
#  [[ 27  21  22]
#   [ 22  18  21]
#   [ 20  17  21]
#   ...
#   [ 81  68  77]
#   [102  94 100]
#   [131 127 138]]
#
#  [[ 22  21  24]
#   [ 21  20  23]
#   [ 20  20  20]
#   ...
#   [101  86  84]
#   [ 87  81  89]
#   [147 144 167]]
#
#  ...
#
#  [[ 48  59 105]
#   [ 43  45 114]
#   [ 47  42 124]
#   ...
#   [ 19  33  52]
#   [ 24  38  58]
#   [ 25  39  59]]
#
#  [[ 42  53  98]
#   [ 48  44 117]
#   [ 57  44 134]
#   ...
#   [ 15  29  50]
#   [ 24  37  58]
#   [ 25  38  60]]
#
#  [[ 43  57  95]
#   [ 42  41 108]
#   [ 44  34 121]
#   ...
#   [ 27  41  61]
#   [ 21  34  56]
#   [ 22  35  57]]]
# [[[ 16  17  19]
#   [ 19  20  21]
#   [ 18  19  20]
#   ...
#   [141 119 118]
#   [255 251 255]
#   [177 151 152]]
#
#  [[ 23  20  26]
#   [ 21  20  24]
#   [ 20  19  22]
#   ...
#   [166 140 144]
#   [255 249 255]
#   [213 190 195]]
#
#  [[ 19  15  22]
#   [ 21  19  23]
#   [ 19  18  22]
#   ...
#   [173 147 147]
#   [255 249 255]
#   [203 174 179]]
#
#  ...
#
#  [[ 46  44 121]
#   [ 41  40 120]
#   [ 34  34 114]
#   ...
#   [ 17  27  45]
#   [ 18  29  50]
#   [ 19  30  53]]
#
#  [[ 51  50 125]
#   [ 48  44 123]
#   [ 32  28 109]
#   ...
#   [ 17  25  43]
#   [ 20  27  48]
#   [ 22  30  51]]
#
#  [[ 43  42 118]
#   [ 41  36 116]
#   [ 41  35 116]
#   ...
#   [ 19  26  45]
#   [ 21  30  51]
#   [ 19  31  53]]]
# [[[ 19  19  23]
#   [ 22  19  24]
#   [ 21  19  21]
#   ...
#   [203 184 184]
#   [170 140 146]
#   [ 98  86  95]]
#
#  [[ 15  17  23]
#   [ 20  19  24]
#   [ 20  17  22]
#   ...
#   [237 216 221]
#   [111  70  84]
#   [ 90  68  87]]
#
#  [[ 13  16  20]
#   [ 17  18  23]
#   [ 14  19  20]
#   ...
#   [243 230 233]
#   [141  97 109]
#   [109  87 102]]
#
#  ...
#
#  [[ 43  44 102]
#   [ 37  39 109]
#   [ 40  39 114]
#   ...
#   [ 17  29  50]
#   [ 19  32  55]
#   [ 22  37  60]]
#
#  [[ 42  44 100]
#   [ 46  44 115]
#   [ 49  46 121]
#   ...
#   [ 19  31  51]
#   [ 21  33  56]
#   [ 25  36  61]]
#
#  [[ 43  43  99]
#   [ 48  40 114]
#   [ 53  42 124]
#   ...
#   [ 23  33  51]
#   [ 24  34  55]
#   [ 22  32  56]]]
# [[[ 20  20  24]
#   [ 15  18  21]
#   [ 17  21  25]
#   ...
#   [255 254 255]
#   [189 159 160]
#   [167 135 139]]
#
#  [[ 23  21  24]
#   [ 20  20  22]
#   [ 17  19  21]
#   ...
#   [255 252 254]
#   [212 189 188]
#   [110  65  73]]
#
#  [[ 18  18  22]
#   [ 19  18  20]
#   [ 21  18  21]
#   ...
#   [254 255 254]
#   [223 196 198]
#   [143 105 117]]
#
#  ...
#
#  [[ 50  59 103]
#   [ 42  44 107]
#   [ 46  46 119]
#   ...
#   [ 16  30  49]
#   [ 18  34  55]
#   [ 19  35  57]]
#
#  [[ 41  49  90]
#   [ 42  41 107]
#   [ 48  44 126]
#   ...
#   [ 17  30  50]
#   [ 19  32  53]
#   [ 21  34  56]]
#
#  [[ 37  51  89]
#   [ 37  38 102]
#   [ 49  41 127]
#   ...
#   [ 17  31  50]
#   [ 19  32  53]
#   [ 18  31  53]]]
# [[[ 19  21  26]
#   [ 22  19  24]
#   [ 18  19  21]
#   ...
#   [254 254 255]
#   [254 255 254]
#   [221 194 194]]
#
#  [[ 24  18  28]
#   [ 20  16  21]
#   [ 19  18  20]
#   ...
#   [254 254 255]
#   [251 255 254]
#   [243 219 216]]
#
#  [[ 26  21  28]
#   [ 19  18  23]
#   [ 18  16  21]
#   ...
#   [254 254 255]
#   [252 255 255]
#   [232 212 208]]
#
#  ...
#
#  [[ 40  49  91]
#   [ 48  43 114]
#   [ 47  38 127]
#   ...
#   [ 20  31  51]
#   [ 21  32  54]
#   [ 25  35  60]]
#
#  [[ 50  65  99]
#   [ 44  45 109]
#   [ 48  44 125]
#   ...
#   [ 20  32  52]
#   [ 19  30  50]
#   [ 18  29  50]]
#
#  [[ 63  77 111]
#   [ 42  48 114]
#   [ 33  31 116]
#   ...
#   [ 23  33  53]
#   [ 22  34  52]
#   [ 22  35  53]]]
# [[[ 20  19  21]
#   [ 19  18  20]
#   [ 17  17  17]
#   ...
#   [255 248 243]
#   [255 255 254]
#   [254 254 255]]
#
#  [[ 19  18  21]
#   [ 18  17  19]
#   [ 19  19  20]
#   ...
#   [255 250 243]
#   [255 255 254]
#   [253 255 255]]
#
#  [[ 21  22  26]
#   [ 19  18  22]
#   [ 22  20  25]
#   ...
#   [255 254 248]
#   [254 255 255]
#   [254 254 255]]
#
#  ...
#
#  [[ 51  55 109]
#   [ 43  37 119]
#   [ 55  43 136]
#   ...
#   [ 22  29  44]
#   [ 23  27  51]
#   [ 23  31  54]]
#
#  [[ 44  47 103]
#   [ 41  34 112]
#   [ 54  43 131]
#   ...
#   [ 19  25  44]
#   [ 25  30  50]
#   [ 24  31  53]]
#
#  [[ 58  59 118]
#   [ 39  34 114]
#   [ 50  43 129]
#   ...
#   [ 24  30  46]
#   [ 24  29  48]
#   [ 28  33  52]]]
# [[[ 20  21  22]
#   [ 20  19  21]
#   [ 22  21  23]
#   ...
#   [255 254 255]
#   [254 255 255]
#   [209 187 186]]
#
#  [[ 22  20  25]
#   [ 19  20  23]
#   [ 20  19  23]
#   ...
#   [254 255 255]
#   [253 255 255]
#   [222 199 200]]
#
#  [[ 13  17  18]
#   [ 18  19  23]
#   [ 20  20  25]
#   ...
#   [255 254 255]
#   [254 255 255]
#   [237 220 222]]
#
#  ...
#
#  [[ 46  50  94]
#   [ 51  41 108]
#   [ 47  40 114]
#   ...
#   [ 24  30  53]
#   [ 23  30  51]
#   [ 28  37  58]]
#
#  [[ 41  52  86]
#   [ 43  45 114]
#   [ 43  45 121]
#   ...
#   [ 22  28  52]
#   [ 25  34  56]
#   [ 26  39  58]]
#
#  [[ 48  65 102]
#   [ 38  40 104]
#   [ 43  42 124]
#   ...
#   [ 24  29  51]
#   [ 25  30  52]
#   [ 23  31  54]]]
# [[[ 16  17  23]
#   [ 15  18  22]
#   [ 17  18  22]
#   ...
#   [255 254 254]
#   [255 254 254]
#   [251 255 255]]
#
#  [[ 20  18  27]
#   [ 20  18  24]
#   [ 23  19  24]
#   ...
#   [255 253 255]
#   [255 255 254]
#   [254 255 254]]
#
#  [[ 21  16  27]
#   [ 19  15  22]
#   [ 24  20  24]
#   ...
#   [255 252 255]
#   [255 255 252]
#   [253 255 253]]
#
#  ...
#
#  [[ 44  55  96]
#   [ 48  46 108]
#   [ 50  39 123]
#   ...
#   [ 12  28  45]
#   [ 16  30  49]
#   [ 19  32  53]]
#
#  [[ 37  48  89]
#   [ 49  51 106]
#   [ 51  45 122]
#   ...
#   [ 16  31  49]
#   [ 16  31  50]
#   [ 20  33  54]]
#
#  [[ 48  58  96]
#   [ 44  48 102]
#   [ 42  38 114]
#   ...
#   [ 19  31  53]
#   [ 17  30  52]
#   [ 19  32  54]]]

# %%
pip install face_recognition
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: face_recognition in c:\programdata\miniconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: face-recognition-models>=0.3.0 in c:\programdata\miniconda3\lib\site-packages (from face_recognition) (0.3.0)
# Requirement already satisfied: Click>=6.0 in c:\users\piyush_kumar\appdata\roaming\python\python312\site-packages (from face_recognition) (8.2.1)
# Requirement already satisfied: dlib>=19.7 in c:\programdata\miniconda3\lib\site-packages (from face_recognition) (19.24.2)
# Requirement already satisfied: numpy in c:\programdata\miniconda3\lib\site-packages (from face_recognition) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\piyush_kumar\appdata\roaming\python\python312\site-packages (from face_recognition) (10.4.0)
# Requirement already satisfied: colorama in c:\programdata\miniconda3\lib\site-packages (from Click>=6.0->face_recognition) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cmake
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cmake in c:\users\piyush_kumar\appdata\roaming\python\python312\site-packages (4.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dlib in c:\programdata\miniconda3\lib\site-packages (19.24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pickle
with open('data/Emails.pkl', 'rb') as f:
            EMAILS = pickle.load(f)
            print(EMAILS)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 import pickle
# ----> 2 with open('data/Emails.pkl', 'rb') as f:
#       3             EMAILS = pickle.load(f)
#       4             print(EMAILS)
#
# File C:\ProgramData\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Emails.pkl'

# %%
with open('data/faces_data.pkl', 'rb') as f:
    FACES=pickle.load(f)
    print(FACES[:5])
# Out:
# [[21 22 15 ... 45 54 53]
#  [32 27 24 ... 35 42 42]
#  [31 30 24 ... 26 39 39]
#  [27 26 23 ... 40 50 52]
#  [41 36 39 ... 22 29 30]]

# %%
with open('data/names.pkl', 'rb') as w:
    LABELS=pickle.load(w)
    print(LABELS)
# Out:
# ['Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush', 'Piyush']

# %%
import cv2
import pickle
import numpy as np
import os
video=cv2.VideoCapture(0)
facedetect=cv2.CascadeClassifier('data/haarcascade_frontalface_default.xml')

faces_data=[]

i=0

name=input("Enter Your Name: ")

while True:
    ret,frame=video.read()
    gray=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces=facedetect.detectMultiScale(gray, 1.3 ,5)
    for (x,y,w,h) in faces:
        print(x,y,w,h)
        crop_img=frame[y:y+h, x:x+w, :]
        resized_img=cv2.resize(crop_img, (50,50))
        if len(faces_data)<=100 and i%10==0:
            faces_data.append(resized_img)
            print(faces_data)
        i=i+1
        cv2.putText(frame, str(len(faces_data)), (50,50), cv2.FONT_HERSHEY_COMPLEX, 1, (50,50,255), 1)
        cv2.rectangle(frame, (x,y), (x+w, y+h), (50,50,255), 1)
    cv2.imshow("Frame",frame)
    k=cv2.waitKey(1)
    if k==ord('q') or len(faces_data)==4:
        break
video.release()
cv2.destroyAllWindows()
# Out:
# Enter Your Name:  piyush
# 262 49 47 47
# [array([[[176, 182, 191],
#         [178, 183, 192],
#         [180, 185, 194],
#         ...,
#         [253, 254, 254],
#         [254, 255, 252],
#         [255, 255, 250]],
#
#        [[177, 182, 191],
#         [178, 183, 192],
#         [180, 185, 195],
#         ...,
#         [252, 254, 254],
#         [254, 255, 252],
#         [255, 255, 250]],
#
#        [[176, 181, 191],
#         [177, 182, 192],
#         [180, 184, 195],
#         ...,
#         [252, 254, 254],
#         [253, 255, 251],
#         [255, 255, 250]],
#
#        ...,
#
#        [[159, 165, 180],
#         [159, 165, 181],
#         [160, 167, 182],
#         ...,
#         [216, 219, 231],
#         [196, 199, 216],
#         [200, 203, 223]],
#
#        [[162, 166, 181],
#         [161, 166, 182],
#         [161, 167, 182],
#         ...,
#         [220, 219, 233],
#         [199, 199, 218],
#         [199, 200, 223]],
#
#        [[163, 167, 181],
#         [162, 167, 182],
#         [161, 168, 182],
#         ...,
#         [225, 221, 237],
#         [207, 206, 225],
#         [204, 203, 226]]], dtype=uint8)]
# 259 46 52 52
# 200 234 122 122
# 259 46 51 51
# 260 46 51 51
# 260 46 51 51
# 194 237 116 116
# 262 49 48 48
# 190 236 121 121
# 260 47 51 51
# 189 238 116 116
# [array([[[176, 182, 191],
#         [178, 183, 192],
#         [180, 185, 194],
#         ...,
#         [253, 254, 254],
#         [254, 255, 252],
#         [255, 255, 250]],
#
#        [[177, 182, 191],
#         [178, 183, 192],
#         [180, 185, 195],
#         ...,
#         [252, 254, 254],
#         [254, 255, 252],
#         [255, 255, 250]],
#
#        [[176, 181, 191],
#         [177, 182, 192],
#         [180, 184, 195],
#         ...,
#         [252, 254, 254],
#         [253, 255, 251],
#         [255, 255, 250]],
#
#        ...,
#
#        [[159, 165, 180],
#         [159, 165, 181],
#         [160, 167, 182],
#         ...,
#         [216, 219, 231],
#         [196, 199, 216],
#         [200, 203, 223]],
#
#        [[162, 166, 181],
#         [161, 166, 182],
#         [161, 167, 182],
#         ...,
#         [220, 219, 233],
#         [199, 199, 218],
#         [199, 200, 223]],
#
#        [[163, 167, 181],
#         [162, 167, 182],
#         [161, 168, 182],
#         ...,
#         [225, 221, 237],
#         [207, 206, 225],
#         [204, 203, 226]]], dtype=uint8), array([[[ 36,  37,  37],
#         [ 36,  35,  38],
#         [ 39,  35,  39],
#         ...,
#         [251, 242, 249],
#         [255, 247, 254],
#         [254, 246, 254]],
#
#        [[ 36,  36,  36],
#         [ 38,  34,  36],
#         [ 37,  32,  35],
#         ...,
#         [255, 249, 255],
#         [254, 242, 254],
#         [254, 244, 254]],
#
#        [[ 35,  34,  35],
#         [ 35,  31,  33],
#         [ 33,  30,  33],
#         ...,
#         [255, 251, 255],
#         [252, 242, 250],
#         [251, 242, 251]],
#
#        ...,
#
#        [[ 64,  72,  76],
#         [ 40,  45,  51],
#         [ 47,  50,  60],
#         ...,
#         [ 81,  88,  95],
#         [ 66,  72,  78],
#         [ 70,  76,  82]],
#
#        [[ 61,  69,  74],
#         [ 51,  59,  65],
#         [ 41,  47,  55],
#         ...,
#         [ 51,  64,  66],
#         [ 52,  57,  66],
#         [ 53,  58,  73]],
#
#        [[ 58,  67,  65],
#         [ 59,  65,  67],
#         [ 48,  54,  60],
#         ...,
#         [ 53,  58,  74],
#         [ 50,  56,  69],
#         [ 57,  60,  72]]], dtype=uint8)]
# 184 236 121 121
# 263 50 46 46
# 184 238 116 116
# 262 49 49 49
# 181 233 122 122
# 260 47 51 51
# 260 47 50 50
# 177 236 120 120
# 262 49 48 48
# 176 234 122 122
# [array([[[176, 182, 191],
#         [178, 183, 192],
#         [180, 185, 194],
#         ...,
#         [253, 254, 254],
#         [254, 255, 252],
#         [255, 255, 250]],
#
#        [[177, 182, 191],
#         [178, 183, 192],
#         [180, 185, 195],
#         ...,
#         [252, 254, 254],
#         [254, 255, 252],
#         [255, 255, 250]],
#
#        [[176, 181, 191],
#         [177, 182, 192],
#         [180, 184, 195],
#         ...,
#         [252, 254, 254],
#         [253, 255, 251],
#         [255, 255, 250]],
#
#        ...,
#
#        [[159, 165, 180],
#         [159, 165, 181],
#         [160, 167, 182],
#         ...,
#         [216, 219, 231],
#         [196, 199, 216],
#         [200, 203, 223]],
#
#        [[162, 166, 181],
#         [161, 166, 182],
#         [161, 167, 182],
#         ...,
#         [220, 219, 233],
#         [199, 199, 218],
#         [199, 200, 223]],
#
#        [[163, 167, 181],
#         [162, 167, 182],
#         [161, 168, 182],
#         ...,
#         [225, 221, 237],
#         [207, 206, 225],
#         [204, 203, 226]]], dtype=uint8), array([[[ 36,  37,  37],
#         [ 36,  35,  38],
#         [ 39,  35,  39],
#         ...,
#         [251, 242, 249],
#         [255, 247, 254],
#         [254, 246, 254]],
#
#        [[ 36,  36,  36],
#         [ 38,  34,  36],
#         [ 37,  32,  35],
#         ...,
#         [255, 249, 255],
#         [254, 242, 254],
#         [254, 244, 254]],
#
#        [[ 35,  34,  35],
#         [ 35,  31,  33],
#         [ 33,  30,  33],
#         ...,
#         [255, 251, 255],
#         [252, 242, 250],
#         [251, 242, 251]],
#
#        ...,
#
#        [[ 64,  72,  76],
#         [ 40,  45,  51],
#         [ 47,  50,  60],
#         ...,
#         [ 81,  88,  95],
#         [ 66,  72,  78],
#         [ 70,  76,  82]],
#
#        [[ 61,  69,  74],
#         [ 51,  59,  65],
#         [ 41,  47,  55],
#         ...,
#         [ 51,  64,  66],
#         [ 52,  57,  66],
#         [ 53,  58,  73]],
#
#        [[ 58,  67,  65],
#         [ 59,  65,  67],
#         [ 48,  54,  60],
#         ...,
#         [ 53,  58,  74],
#         [ 50,  56,  69],
#         [ 57,  60,  72]]], dtype=uint8), array([[[ 47,  51,  58],
#         [ 35,  37,  42],
#         [ 33,  30,  37],
#         ...,
#         [192, 185, 194],
#         [202, 196, 204],
#         [220, 209, 219]],
#
#        [[ 38,  42,  44],
#         [ 27,  29,  33],
#         [ 37,  36,  39],
#         ...,
#         [189, 185, 194],
#         [206, 199, 209],
#         [210, 199, 209]],
#
#        [[ 41,  37,  40],
#         [ 36,  33,  38],
#         [ 34,  31,  38],
#         ...,
#         [192, 186, 194],
#         [206, 198, 208],
#         [214, 200, 212]],
#
#        ...,
#
#        [[ 55,  64,  63],
#         [ 57,  73,  70],
#         [ 62,  80,  77],
#         ...,
#         [101, 104, 116],
#         [ 64,  67,  75],
#         [ 56,  61,  67]],
#
#        [[ 45,  56,  53],
#         [ 48,  58,  58],
#         [ 55,  67,  70],
#         ...,
#         [ 71,  69,  80],
#         [ 64,  62,  74],
#         [ 60,  62,  75]],
#
#        [[ 60,  71,  62],
#         [ 56,  67,  62],
#         [ 52,  62,  63],
#         ...,
#         [ 60,  59,  69],
#         [ 62,  57,  72],
#         [ 53,  54,  70]]], dtype=uint8)]
# 261 47 49 49
# 172 231 128 128
# 261 48 49 49
# 174 233 125 125
# 176 236 121 121
# 262 50 47 47
# 176 236 120 120
# 261 48 49 49
# 174 232 126 126
# 177 235 120 120
# [array([[[176, 182, 191],
#         [178, 183, 192],
#         [180, 185, 194],
#         ...,
#         [253, 254, 254],
#         [254, 255, 252],
#         [255, 255, 250]],
#
#        [[177, 182, 191],
#         [178, 183, 192],
#         [180, 185, 195],
#         ...,
#         [252, 254, 254],
#         [254, 255, 252],
#         [255, 255, 250]],
#
#        [[176, 181, 191],
#         [177, 182, 192],
#         [180, 184, 195],
#         ...,
#         [252, 254, 254],
#         [253, 255, 251],
#         [255, 255, 250]],
#
#        ...,
#
#        [[159, 165, 180],
#         [159, 165, 181],
#         [160, 167, 182],
#         ...,
#         [216, 219, 231],
#         [196, 199, 216],
#         [200, 203, 223]],
#
#        [[162, 166, 181],
#         [161, 166, 182],
#         [161, 167, 182],
#         ...,
#         [220, 219, 233],
#         [199, 199, 218],
#         [199, 200, 223]],
#
#        [[163, 167, 181],
#         [162, 167, 182],
#         [161, 168, 182],
#         ...,
#         [225, 221, 237],
#         [207, 206, 225],
#         [204, 203, 226]]], dtype=uint8), array([[[ 36,  37,  37],
#         [ 36,  35,  38],
#         [ 39,  35,  39],
#         ...,
#         [251, 242, 249],
#         [255, 247, 254],
#         [254, 246, 254]],
#
#        [[ 36,  36,  36],
#         [ 38,  34,  36],
#         [ 37,  32,  35],
#         ...,
#         [255, 249, 255],
#         [254, 242, 254],
#         [254, 244, 254]],
#
#        [[ 35,  34,  35],
#         [ 35,  31,  33],
#         [ 33,  30,  33],
#         ...,
#         [255, 251, 255],
#         [252, 242, 250],
#         [251, 242, 251]],
#
#        ...,
#
#        [[ 64,  72,  76],
#         [ 40,  45,  51],
#         [ 47,  50,  60],
#         ...,
#         [ 81,  88,  95],
#         [ 66,  72,  78],
#         [ 70,  76,  82]],
#
#        [[ 61,  69,  74],
#         [ 51,  59,  65],
#         [ 41,  47,  55],
#         ...,
#         [ 51,  64,  66],
#         [ 52,  57,  66],
#         [ 53,  58,  73]],
#
#        [[ 58,  67,  65],
#         [ 59,  65,  67],
#         [ 48,  54,  60],
#         ...,
#         [ 53,  58,  74],
#         [ 50,  56,  69],
#         [ 57,  60,  72]]], dtype=uint8), array([[[ 47,  51,  58],
#         [ 35,  37,  42],
#         [ 33,  30,  37],
#         ...,
#         [192, 185, 194],
#         [202, 196, 204],
#         [220, 209, 219]],
#
#        [[ 38,  42,  44],
#         [ 27,  29,  33],
#         [ 37,  36,  39],
#         ...,
#         [189, 185, 194],
#         [206, 199, 209],
#         [210, 199, 209]],
#
#        [[ 41,  37,  40],
#         [ 36,  33,  38],
#         [ 34,  31,  38],
#         ...,
#         [192, 186, 194],
#         [206, 198, 208],
#         [214, 200, 212]],
#
#        ...,
#
#        [[ 55,  64,  63],
#         [ 57,  73,  70],
#         [ 62,  80,  77],
#         ...,
#         [101, 104, 116],
#         [ 64,  67,  75],
#         [ 56,  61,  67]],
#
#        [[ 45,  56,  53],
#         [ 48,  58,  58],
#         [ 55,  67,  70],
#         ...,
#         [ 71,  69,  80],
#         [ 64,  62,  74],
#         [ 60,  62,  75]],
#
#        [[ 60,  71,  62],
#         [ 56,  67,  62],
#         [ 52,  62,  63],
#         ...,
#         [ 60,  59,  69],
#         [ 62,  57,  72],
#         [ 53,  54,  70]]], dtype=uint8), array([[[ 49,  45,  46],
#         [ 38,  32,  33],
#         [ 40,  32,  36],
#         ...,
#         [192, 183, 192],
#         [195, 193, 201],
#         [208, 203, 212]],
#
#        [[ 40,  41,  39],
#         [ 37,  35,  36],
#         [ 34,  30,  31],
#         ...,
#         [186, 180, 191],
#         [202, 199, 209],
#         [204, 198, 208]],
#
#        [[ 39,  31,  37],
#         [ 42,  35,  39],
#         [ 39,  33,  32],
#         ...,
#         [188, 183, 193],
#         [199, 196, 205],
#         [201, 194, 203]],
#
#        ...,
#
#        [[ 59,  69,  69],
#         [ 65,  75,  75],
#         [ 54,  62,  64],
#         ...,
#         [139, 144, 149],
#         [108, 109, 115],
#         [ 62,  64,  70]],
#
#        [[ 54,  64,  65],
#         [ 57,  64,  68],
#         [ 65,  72,  76],
#         ...,
#         [127, 122, 131],
#         [ 76,  68,  78],
#         [ 65,  58,  68]],
#
#        [[ 50,  56,  58],
#         [ 49,  56,  59],
#         [ 65,  72,  78],
#         ...,
#         [ 90,  81,  97],
#         [ 67,  60,  72],
#         [ 66,  59,  70]]], dtype=uint8)]
